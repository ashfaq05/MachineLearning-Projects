# %%
from tensorflow.keras.models import Sequential

from tensorflow.keras.layers import Conv2D,MaxPooling2D,Dropout,Flatten,Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
for dirname, _, filenames in os.walk('D:\JUPYTER\1_Fase_mask_project\Masks Dataset'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
main_dir = '/content/drive/MyDrive/Colab Notebooks/1_Fase_mask_project/Masks Dataset'
train_dir = os.path.join(main_dir,'Train')
test_dir = os.path.join(main_dir,'Test')
validation_dir = os.path.join(main_dir,'Validation')

train_mask_dir = os.path.join(train_dir,'Mask')
train_non_mask_dir = os.path.join(train_dir,'Non Mask')

# %%
train_mask_dir_names = os.listdir(train_mask_dir)
train_non_mask_dir_names = os.listdir(train_non_mask_dir)

print(train_mask_dir_names[:10])
print(train_non_mask_dir_names[:10])
# Out:
# ['0018.jpg', '0042.jpg', '0003.jpg', '0029.jpg', '0006.jpg', '0019.jpg', '0022.jpg', '0027.jpg', '0040.jpg', '0037.jpg']
# ['153.jpg', '151.jpg', '12.jpg', '13.jpg', '134.jpg', '140.jpg', '107.jpg', '152.jpg', '139.jpg', '130.jpg']

# %%
import matplotlib.image as npimg
nrows=4
ncols=4
plt.figure(figsize=(12,12))

mask_pic = []

for i in train_mask_dir_names[0:8]:
  mask_pic.append(os.path.join(train_mask_dir,i))

no_mask_pic = []

for i in train_non_mask_dir_names[0:8]:
  no_mask_pic.append(os.path.join(train_non_mask_dir,i))

# %%
print(mask_pic)
print(no_mask_pic)
# Out:
# ['/content/drive/MyDrive/Colab Notebooks/1_Fase_mask_project/Masks Dataset/Train/Mask/0018.jpg', '/content/drive/MyDrive/Colab Notebooks/1_Fase_mask_project/Masks Dataset/Train/Mask/0042.jpg', '/content/drive/MyDrive/Colab Notebooks/1_Fase_mask_project/Masks Dataset/Train/Mask/0003.jpg', '/content/drive/MyDrive/Colab Notebooks/1_Fase_mask_project/Masks Dataset/Train/Mask/0029.jpg', '/content/drive/MyDrive/Colab Notebooks/1_Fase_mask_project/Masks Dataset/Train/Mask/0006.jpg', '/content/drive/MyDrive/Colab Notebooks/1_Fase_mask_project/Masks Dataset/Train/Mask/0019.jpg', '/content/drive/MyDrive/Colab Notebooks/1_Fase_mask_project/Masks Dataset/Train/Mask/0022.jpg', '/content/drive/MyDrive/Colab Notebooks/1_Fase_mask_project/Masks Dataset/Train/Mask/0027.jpg']
# ['/content/drive/MyDrive/Colab Notebooks/1_Fase_mask_project/Masks Dataset/Train/Non Mask/153.jpg', '/content/drive/MyDrive/Colab Notebooks/1_Fase_mask_project/Masks Dataset/Train/Non Mask/151.jpg', '/content/drive/MyDrive/Colab Notebooks/1_Fase_mask_project/Masks Dataset/Train/Non Mask/12.jpg', '/content/drive/MyDrive/Colab Notebooks/1_Fase_mask_project/Masks Dataset/Train/Non Mask/13.jpg', '/content/drive/MyDrive/Colab Notebooks/1_Fase_mask_project/Masks Dataset/Train/Non Mask/134.jpg', '/content/drive/MyDrive/Colab Notebooks/1_Fase_mask_project/Masks Dataset/Train/Non Mask/140.jpg', '/content/drive/MyDrive/Colab Notebooks/1_Fase_mask_project/Masks Dataset/Train/Non Mask/107.jpg', '/content/drive/MyDrive/Colab Notebooks/1_Fase_mask_project/Masks Dataset/Train/Non Mask/152.jpg']

# %%
merged_list = mask_pic + no_mask_pic

for i in range(0,len(merged_list)):
  data = merged_list[i].split('/',4)[4]
  sp = plt.subplot(nrows,ncols,i+1)
  plt.axis('Off')
  image = npimg.imread(merged_list[i])
  sp.set_title(data,fontsize=10)
  plt.imshow(image,cmap='gray')
plt.show()

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   zoom_range=0.2,
                                   rotation_range=40,
                                   horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1./255)
validation_datagen = ImageDataGenerator(rescale=1./255)

train_images_generator = train_datagen.flow_from_directory(train_dir,
                                                           target_size=(180,180),
                                                           batch_size=32,
                                                           class_mode='binary')

test_images_generator = test_datagen.flow_from_directory(test_dir,
                                                           target_size=(180,180),
                                                           batch_size=32,
                                                           class_mode='binary')

valid_images_generator = validation_datagen.flow_from_directory(validation_dir,
                                                           target_size=(180,180),
                                                           batch_size=32,
                                                           class_mode='binary')
# Out:
# Found 600 images belonging to 2 classes.
# Found 100 images belonging to 2 classes.
# Found 306 images belonging to 2 classes.

# %%
train_images_generator.class_indices
# Out:
# {'Mask': 0, 'Non Mask': 1}

# %%
train_images_generator.image_shape
# Out:
# (180, 180, 3)

# %%
model = Sequential()
model.add(Conv2D(32,(3,3),padding='SAME',activation='relu',input_shape=(180,180,3)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.3))

model.add(Conv2D(64,(3,3),padding='SAME',activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Flatten())

model.add(Dense
# 19/19 [==============================] - 14s 739ms/step - loss: 0.0967 - accuracy: 0.9695 - val_loss: 0.3383 - val_accuracy: 0.9281
# Epoch 94/100
# 19/19 [==============================] - 14s 734ms/step - loss: 0.0818 - accuracy: 0.9684 - val_loss: 0.2629 - val_accuracy: 0.9216
# Epoch 95/100
# 19/19 [==============================] - 14s 735ms/step - loss: 0.0448 - accuracy: 0.9830 - val_loss: 0.2927 - val_accuracy: 0.9150
# Epoch 96/100
# 19/19 [==============================] - 14s 746ms/step - loss: 0.0482 - accuracy: 0.9776 - val_loss: 0.3391 - val_accuracy: 0.9150
# Epoch 97/100
# 19/19 [==============================] - 14s 732ms/step - loss: 0.0784 - accuracy: 0.9661 - val_loss: 0.2792 - val_accuracy: 0.9281
# Epoch 98/100
# 19/19 [==============================] - 14s 750ms/step - loss: 0.0513 - accuracy: 0.9843 - val_loss: 0.3257 - val_accuracy: 0.9248
# Epoch 99/100
# 19/19 [==============================] - 14s 740ms/step - loss: 0.0357 - accuracy: 0.9818 - val_loss: 0.2782 - val_accuracy: 0.9281
# Epoch 100/100
# 19/19 [==============================] - 14s 742ms/step - loss: 0.0523 - accuracy: 0.9870 - val_loss: 0.2627 - val_accuracy: 0.9281

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['Training','Validation'])
plt.title("Training And Validation Loss")
plt.xlabel("Epochs")
# Out:
# Text(0.5, 0, 'Epochs')

# %%
test_loss , test_acc = model.evaluate(test_images_generator)

print("Test Loss: {} Test Accuracy: {}".format(test_loss,test_acc))
# Out:
# 4/4 [==============================] - 31s 10s/step - loss: 0.1480 - accuracy: 0.9600
# Test Loss: 0.14801110327243805 Test Accuracy: 0.9599999785423279

# %%
model.save('face_mask_detection.h5')

# %%
import matplotlib.image as mpimg
from keras.preprocessing import image

def test_image_mask_nomask(path):
    im = mpimg.imread(path)
    plt.imshow(im)
    
    img = image.load_img(path,target_size=(180,180))
    img = image.img_to_array(img)
    img = np.expand_dims(img,axis=0)
    prediction = model.predict(img)
    if prediction == 0:
        
        print("Person Wearing A Mask")

    else:
        print("Person Not Wearing A Mask")

# %%
test_image_mask_nomask('/content/drive/MyDrive/Colab Notebooks/1_Fase_mask_project/Masks Dataset/Test/Non Mask/real_01049.jpg')
# Out:
# Person Not Wearing A Mask

# %%
test_image_mask_nomask('/content/drive/MyDrive/Colab Notebooks/1_Fase_mask_project/Masks Dataset/Test/Mask/2070.jpg')
# Out:
# Person Wearing A Mask

# %%
test_image_mask_nomask('/content/drive/MyDrive/Colab Notebooks/1_Fase_mask_project/Masks Dataset/Validation/Mask/1701.jpg')
# Out:
# Person Wearing A Mask

# %%
test_image_mask_nomask('/content/drive/MyDrive/Colab Notebooks/1_Fase_mask_project/Masks Dataset/Validation/Non Mask/real_00001.jpg')
# Out:
# Person Not Wearing A Mask

# %%
test_image_mask_nomask("/content/drive/MyDrive/Colab Notebooks/1_Fase_mask_project/model_finel_test_data/000.jpg")
# Out:
# Person Not Wearing A Mask

# %%
test_image_mask_nomask("/content/drive/MyDrive/Colab Notebooks/1_Fase_mask_project/model_finel_test_data/001.jpg")
# Out:
# Person Wearing A Mask

# %%
test_image_mask_nomask("/content/drive/MyDrive/Colab Notebooks/1_Fase_mask_project/model_finel_test_data/pn.jpeg")
# Out:
# Person Not Wearing A Mask

# %%
test_image_mask_nomask("/content/drive/MyDrive/Colab Notebooks/1_Fase_mask_project/model_finel_test_data/zm.png")
# Out:
# Person Wearing A Mask
